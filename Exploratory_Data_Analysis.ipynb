# %%
import sys, re
from pandas import *
import imdb
import timeit
import MySQLdb as mdb

# %%
df = read_table('top_movies_with_ratings.txt')

# %%
con = mdb.connect('localhost', 'root', '', 'imdb');
cur = con.cursor()

# %%
cur.execute('SELECT info, COUNT(*) AS tot_num FROM movie_genre GROUP BY info ORDER BY tot_num DESC;')
genre_num = DataFrame(list(cur.fetchall()), columns = ['genre', 'tot_num'])
genre_num
# Out:
#           genre  tot_num
# 0         Drama     2854
# 1        Comedy     2068
# 2      Thriller     1744
# 3        Action     1262
# 4       Romance     1226
# 5         Crime     1129
# 6     Adventure      898
# 7        Sci-Fi      672
# 8       Mystery      634
# 9        Horror      630
# 10      Fantasy      594
# 11       Family      517
# 12    Biography      284
# 13    Animation      265
# 14          War      236
# 15      History      194
# 16        Music      194
# 17        Sport      191
# 18      Musical      149
# 19      Western      104
# 20  Documentary       74
# 21    Film-Noir       33
# 22        Short       14
# 23    Game-Show        1
# 24        Adult        1
#
# [25 rows x 2 columns]
